# %%
import selenium.webdriver

driver = selenium.webdriver.Firefox(executable_path='geckodriver')
driver.get("http://web.whatsapp.com")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.9/site-packages/selenium/webdriver/common/service.py in start(self)
#      71             cmd.extend(self.command_line_args())
# ---> 72             self.process = subprocess.Popen(cmd, env=self.env,
#      73                                             close_fds=platform.system() != 'Windows',
#
# /usr/local/Cellar/python@3.9/3.9.6/Frameworks/Python.framework/Versions/3.9/lib/python3.9/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# /usr/local/Cellar/python@3.9/3.9.6/Frameworks/Python.framework/Versions/3.9/lib/python3.9/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1820                         err_msg = os.strerror(errno_num)
# -> 1821                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1822                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/geckodriver'
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# /var/folders/sg/3_rb7j750ngc4j00zxmjxn780000gn/T/ipykernel_18305/3038600124.py in <module>
#       1 import selenium.webdriver
#       2
# ----> 3 driver = selenium.webdriver.Firefox(executable_path='/geckodriver')
#       4 driver.get("http://web.whatsapp.com")
#
# /usr/local/lib/python3.9/site-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, options, service_log_path, firefox_options, service_args, desired_capabilities, log_path, keep_alive)
#     162                 service_args=service_args,
#     163                 log_path=service_log_path)
# --> 164             self.service.start()
#     165
#     166             capabilities.update(options.to_capabilities())
#
# /usr/local/lib/python3.9/site-packages/selenium/webdriver/common/service.py in start(self)
#      79         except OSError as err:
#      80             if err.errno == errno.ENOENT:
# ---> 81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
#      83                         os.path.basename(self.path), self.start_error_message)
#
# WebDriverException: Message: 'geckodriver' executable needs to be in PATH.

# %%
elements = driver.find_elements_by_class_name("_22Msk")
print(len(elements))
# Out:
# 8

# %%
messages=[]
for i in range(len(elements)):
    print(elements[i].text)
    messages.append(elements[len(elements)-i-1].text) 
    input()
# Out:
# Apj Namrata Maths Ma'am
# Pls wait
# 08:06
#
# Everyone join the meeting
# 08:10
#
# +91 98118 49318
# Nasreen Mohsin
# Join our Cloud HD Video Meeting
# Zoom is the leader in modern enterprise video communications, with an easy, reliable cloud platform for video and audio conferencing, chat, and webinars across mobile, desktop, and room systems. Zoom Rooms is the original software-based conference room solution used around the world in board, conference, huddle, and training rooms, as well as executive offices and classrooms. Founded in 2011, Zoom helps businesses and organizations bring their teams together in a frictionless environment to get more done. Zoom is a publicly traded company headquartered in San Jose, CA.
# us04web.zoom.us
# nasreen mohsin is inviting you to a scheduled Zoom meeting.
#
# Topic: nasreen mohsin's Zoom Meeting
# Time: Jul 29, 2021 10:10 AM India
#
# Join Zoom Meeting
# https://us04web.zoom.us/j/77043321968?pwd=K2k2cC80S3ZRUzNNN1gwZ3BLTGFKdz09
#
# Meeting ID: 770 4332 1968
# Passcode: f5s0rg
# 08:37
#
# Apj Namrata Maths Ma'am
# Forwarded
# Class VIII (2021-22)
# Syllabus for Unit test 1
# Subject: Mathematics
#
# Chapter1- Rational numbers
# Chapter2- Linear equations in one variable
# Chapter 3 - Understanding quadrilaterals Till ex 3.2
# 08:42
#
# Apj Mukta Ma'am Science
# Mukta Rakheja is inviting you to a scheduled Zoom meeting.
#
# Topic: Mukta Rakheja's Zoom Meeting
# Time: Jul 29, 2021 09:10 AM Mumbai, Kolkata, New Delhi
#
# Join Zoom Meeting
# https://zoom.us/j/94649203302?pwd=ZU9iUGhXQklld3lTUFdRSUxsRWJLUT09
#
# Meeting ID: 946 4920 3302
# Passcode: 0sXvNs
# 08:55
#
# Apj Kanchan Ma'am English
# Kanchan Lata Pant is inviting you to a scheduled Zoom meeting.
#
# Topic: Kanchan Lata Pant's Zoom Meeting
# Time: Jul 29, 2021 08:00 AM India
#
# Join Zoom Meeting
# https://us02web.zoom.us/j/7123334384?pwd=clZxL0dSUDFJOWRrQ2p5eXFtSHAxZz09
#
# Meeting ID: 712 333 4384
# Passcode: ASTUTE
# 11:00
#
# Join at 11.20 am
# 11:00
#
# APJ Swati Ma'am SSC
# Join our Cloud HD Video Meeting
# Zoom is the leader in modern enterprise video communications, with an easy, reliable cloud platform for video and audio conferencing, chat, and webinars across mobile, desktop, and room systems. Zoom Rooms is the original software-based conference room solution used around the world in board, conference, huddle, and training rooms, as well as executive offices and classrooms. Founded in 2011, Zoom helps businesses and organizations bring their teams together in a frictionless environment to get more done. Zoom is a publicly traded company headquartered in San Jose, CA.
# zoom.us
# Swati Singh is inviting you to a scheduled Zoom meeting.
#
# Topic: Swati Singh's Zoom Meeting
# Time: Jul 29, 2021 01:20 PM India
#
# Join Zoom Meeting
# https://zoom.us/j/97614925335?pwd=NklkdmdwRFZCNTdHZXRVckcxUXhnQT09
#
# Meeting ID: 976 1492 5335
# Passcode: xHg4B5
# 12:49

# %%
#print(messages)
info=[]
def get_content(message):
    msg=message.split()
    #print(msg)
    
    i=0
    name=''
    while (msg[i] != "Join" and msg[i] != "is" ):
        name=name+msg[i]+' '
        if msg[i] == "Ma'am":
            break
        i+=1
        if i >= len(msg):
            break
        
    print("Name:", name)
    
    
    i=0
    time=''
    while(msg[i] != 'Time:' ):
        i+=1
        if i >= len(msg):
            break
    i+=1        
    if i < len(msg):
                       
        while msg[i] != 'Join' :
            time= time+ msg[i] + ' '
            if msg[i]=='India' :
                break
            i+=1
            if i >= len(msg):
                break
            
    print("time:", time)
    
    
    
    i=0
    link=''
    has_link=False
    
    while(i < len(msg)):
        if (msg[i].startswith('https')):
            has_link=True
            link=msg[i]
        i+=1    
        
    print("link:", link)
        
    
        
    print("\n")
    '''{"teacher": get_teacher(message),
                 "link" : get_link(message),
                 "time_meet" : get_time(message),
                 "id" : get_id(message),
                 "pass" : get_pass(message)
                }'''
def update_info(messages):
    info=[]
    for message in messages:
        get_content(message)

        
update_info(messages)
# Out:
# Name: APJ Swati Ma'am
# time: Jul 29, 2021 01:20 PM India
# link: https://zoom.us/j/97614925335?pwd=NklkdmdwRFZCNTdHZXRVckcxUXhnQT09
#
#
# Name:
# time:
# link:
#
#
# Name: Apj Kanchan Ma'am
# time: Jul 29, 2021 08:00 AM India
# link: https://us02web.zoom.us/j/7123334384?pwd=clZxL0dSUDFJOWRrQ2p5eXFtSHAxZz09
#
#
# Name: Apj Mukta Ma'am
# time: Jul 29, 2021 09:10 AM Mumbai, Kolkata, New Delhi
# link: https://zoom.us/j/94649203302?pwd=ZU9iUGhXQklld3lTUFdRSUxsRWJLUT09
#
#
# Name: Apj Namrata Maths Ma'am
# time:
# link:
#
#
# Name: +91 98118 49318 Nasreen Mohsin
# time: Jul 29, 2021 10:10 AM India
# link: https://us04web.zoom.us/j/77043321968?pwd=K2k2cC80S3ZRUzNNN1gwZ3BLTGFKdz09
#
#
# Name: Everyone join the meeting 08:10
# time:
# link:
#
#
# Name: Apj Namrata Maths Ma'am
# time:
# link:
